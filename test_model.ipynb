# %%
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # our first model

# %%
model = tf.keras.models.load_model('saved_model/my_first_model.h5', compile = True)

# %%
img_path = 'image\\data\\vehicles\\1.png'

# %%
img = image.load_img(img_path, target_size=(64, 64))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 64, 64, 3)

# %%
preds = model.predict(x)

# %%
predictions = np.argmax(preds)

# %%
predictions
# Out:
# 0

# %% [markdown]
# le model ne marche pas, nous lui avons fourni une image qui contient une voiture et il sort 0 comme class

# %% [markdown]
# # Our second model

# %%
model2 = tf.keras.models.load_model('saved_model/tansfer_model.h5', compile = True)

# %%
img_path = 'image\\data\\non-vehicles\\extra2.png'
img = image.load_img(img_path, target_size=(64, 64))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
preds = model2.predict(x)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029D24294C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = np.argmax(preds)

# %%
predictions
# Out:
# 0

# %%
img_path = 'image\\data\\vehicles\\1.png'
img = image.load_img(img_path, target_size=(64, 64))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
preds = model2.predict(x)
prediction2 = np.argmax(preds)

# %%
prediction2
# Out:
# 1

# %%
img_path = 'image\\not_seen\\test_data.jpg'
img = image.load_img(img_path, target_size=(64, 64))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
preds = model2.predict(x)
prediction3 = np.argmax(preds)

# %%
prediction3
# Out:
# 1
